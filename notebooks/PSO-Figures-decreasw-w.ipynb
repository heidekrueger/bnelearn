# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# custom colors
colors = [(0/255.,191/255.,196/255.), (248/255.,118/255.,109/255.), (150/255.,120/255.,170/255.), (200/255.,150/255.,120/255.)]

# %%
#w till ~ 01

fig, ax = plt.subplots(figsize=(5, 3))

def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

agg = [percentile(25), percentile(75), 'median']

# 1-01
color = colors[0]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-1-01/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 1.0$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 08-01
color = colors[1]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-08-01/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.8$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 07-01
color = colors[2]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-07-01/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.7$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 06-01
color = colors[3]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-06-01/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.6$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# plot
ax.set_yscale('log')
ax.set_xlim([0, max(x)])
ax.set_ylim([1e-4, 1e0])
plt.grid(which='major', alpha=.5, linestyle='--')
ax.set_xlabel('iteration $t$')
ax.set_ylabel('utility loss $\mathcal{L}$')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('decrease_w_min-01.pdf', format='pdf')
plt.show()

# %%
#w till ~ 02

fig, ax = plt.subplots(figsize=(5, 3))

def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

agg = [percentile(25), percentile(75), 'median']


# 08-02
color = colors[0]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-08-02/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.8$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 07-02
color = colors[1]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-07-02/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.7$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 06-02
color = colors[2]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-06-02/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.6$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 05-02
color = colors[3]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-08-w-05-02/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.5$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# plot
ax.set_yscale('log')
ax.set_xlim([0, max(x)])
ax.set_ylim([1e-4, 1e0])
plt.grid(which='major', alpha=.5, linestyle='--')
ax.set_xlabel('iteration $t$')
ax.set_ylabel('utility loss $\mathcal{L}$')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('decrease_w_min-02.pdf', format='pdf')
plt.show()

# %%
#w till ~ 02 with c = 1.5

fig, ax = plt.subplots(figsize=(5, 3))

def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

agg = [percentile(25), percentile(75), 'median']

# 08-02
color = colors[0]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-08-w-08-02-c/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.8$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 07-02
color = colors[1]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-08-w-07-02-c/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.7$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 06-02
color = colors[2]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-08-w-06-02-c/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.6$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 05-02
color = colors[3]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-08-w-05-02-c/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w_{max} = 0.5$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# plot
ax.set_yscale('log')
ax.set_xlim([0, max(x)])
ax.set_ylim([1e-4, 1e0])
plt.grid(which='major', alpha=.5, linestyle='--')
ax.set_xlabel('iteration $t$')
ax.set_ylabel('utility loss $\mathcal{L}$')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('decrease_w_min-02-c-15.pdf', format='pdf')
plt.show()

# %%
#w 06 ~ 02

fig, ax = plt.subplots(figsize=(5, 3))

def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

agg = [percentile(25), percentile(75), 'median']

# 06-01
color = colors[0]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-06-01/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w = 0.6 - 0.1$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# 06-02
color = colors[1]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-07-w-06-02/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w = 0.6 - 0.2$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# standard
color = colors[2]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-08-reeval-10/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w = 0.5$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# plot
ax.set_yscale('log')
ax.set_xlim([0, max(x)])
ax.set_ylim([1e-4, 1e0])
plt.grid(which='major', alpha=.5, linestyle='--')
ax.set_xlabel('iteration $t$')
ax.set_ylabel('utility loss $\mathcal{L}$')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('decrease_w_max-06.pdf', format='pdf')
plt.show()

# %%
#w 05 ~ 02

fig, ax = plt.subplots(figsize=(5, 3))

def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

agg = [percentile(25), percentile(75), 'median']


# 05-02
color = colors[1]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-08-w-05-02/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w = 0.5-0.2$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)

# standard
color = colors[0]
df = pd.read_csv('/home/froehlich/bnelearn/experiments/decrease/PSOLearner/single_item/first_price/uniform/symmetric/risk_neutral/2p/07-08-reeval-10/full_results.csv')
df_sub = df[df['tag'] == 'eval/epsilon_relative'][['epoch', 'value']]
df_sub = df_sub.groupby('epoch').agg(agg)
df_sub.columns = ['min', 'max', 'mean']
df_sub.head()
x, y, mi, ma = df_sub.index, df_sub['mean'], df_sub['min'], df_sub['max']
plt.plot(x, y, '-', label='$w=0.5$', color=color)
plt.fill_between(x, mi, ma, alpha=.2, color=color)


# plot
ax.set_yscale('log')
ax.set_xlim([0, max(x)])
ax.set_ylim([1e-4, 1e0])
plt.grid(which='major', alpha=.5, linestyle='--')
ax.set_xlabel('iteration $t$')
ax.set_ylabel('utility loss $\mathcal{L}$')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('decrease_w_best.pdf', format='pdf')
plt.show()
